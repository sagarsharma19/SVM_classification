# %%
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
from keras.preprocessing import image

# %% [markdown]
# ## creating labels even though csv file for labels is given

# %%
P=Path('../pokemon(p,b,c)/pokemon_images')

label_dict={'Pikachu':0,'Bulbasaur':1,'Charmender':2}
image_data=[]
labels=[]
    

dirs=P.glob('*')
for folder_name in dirs:
    
    label= str(folder_name).split('\\')[-1]
    
    for image_name in folder_name.glob('*.jpg'):
        
        img=image.load_img(image_name,target_size=(32,32))
        img_array=image.img_to_array(img)
        image_data.append(img_array)
        labels.append(label_dict[label])

# %%
print(len(labels))
print(len(image_data))
# Out:
# 304
# 304

# %%
image_data=np.asarray(image_data,dtype='float32')/255.0
labels=np.asarray(labels)

# %%
image_data.shape
# Out:
# (304, 32, 32, 3)

# %%
labels.shape
# Out:
# (304,)

# %%
import random

combined = list(zip(image_data,labels))

random.shuffle(combined)

image_data[:],labels[:]=zip(*combined)

# %%
def drawimage(img):
    plt.imshow(img)
    plt.show()
    return

# %%
for i in range(10):
    drawimage(image_data[i])

# %%
class SVM:
    
    def __init__(self,C=1.0):
        self.C=C
        self.W=0
        self.b=0
        
    def hindgeloss(self,W,b,X,Y):
        loss=0.0
        
        loss+=0.5*np.dot(W,W.T)
        
        m=X.shape[0]
        
        for i in range(m):
            ti=Y[i]*(np.dot(W,X[i].T)+b)
            loss+=self.C*max(0,(1-ti))
            
        return loss[0][0]
    
    def fit(self,X,Y,batch_size=100,learning_rate=0.0001,maxItr=100):
        no_of_samples = X.shape[0]
        no_of_features = X.shape[1]
        
        n=learning_rate
        c=self.C
        
        W=np.zeros((1,no_of_features))
        bias=0.0
        
#         print(self.hindgeloss(W,bias,X,Y))
        
        
    
        losses=[]
        for i in range(maxItr):
            
            
            l=self.hindgeloss(W,bias,X,Y)
            losses.append(l)
            ids=np.arange(no_of_samples)
            np.random.shuffle(ids)
            
            for batch_start in range(0,no_of_samples,batch_size):
                gradw=0.0
                gradb=0.0
                for j in range (batch_start,batch_start+batch_size):
                    if j<no_of_samples:
                        i=ids[j]
                        ti=Y[i]*(np.dot(W,X[i].T)+bias)
                        
                        if ti>1:
                            gradw+=0
                            gradb+=0
                        
                        else:
                            gradw+=c*Y[i]*X[i]
                            gradb+=c*Y[i]
                            
                            
                W=W-n*W+n*gradw
                bias=bias+n*gradb
    
        self.W=W
        self.b=bias
        return W,bias,losses

# %%
M=image_data.shape[0]
image_data=image_data.reshape((M,-1))

print(image_data.shape)
print(labels.shape)
# Out:
# (304, 3072)
# (304,)

# %%
CLASSES=len(np.unique(labels))
print(CLASSES)
# Out:
# 3

# %%
def classwisedata(x,y):
    
    data={}
    
    for i in range(CLASSES):
        data[i]=[]
        
        
    for i in range(x.shape[0]):
        data[y[i]].append(x[i])
        
        
    for k in data.keys():
        data[k]=np.array(data[k])
        
        
    return data

# %%
data=classwisedata(image_data,labels)

# %%
print(data[0].shape)
print(data[1].shape)
print(data[2].shape)
# Out:
# (101, 3072)
# (101, 3072)
# (102, 3072)

# %%
def getdatapairforSVM(d1,d2):
    l1,l2=d1.shape[0],d2.shape[0]
    
    samples=l1+l2
    features=d1.shape[1]
    
    
    data_pair=np.zeros((samples,features))
    data_labels=np.zeros((samples,))
    
    data_pair[:l1,:]=d1
    data_pair[l1:,:]=d2
    
    data_labels[:l1]=-1
    data_labels[l1:]=1
    
    
    return data_pair,data_labels

# %%
mysvm=SVM()

# %%
def trainSVMs(x,y):
    
    svm_classifier={}
    
    for i in range(CLASSES):
        svm_classifier[i]={}
        for j in range (i+1,CLASSES):
            xpair,ypair=getdatapairforSVM(data[i],data[j])
            wts,b,loss=mysvm.fit(xpair,ypair)
            
            svm_classifier[i][j]=(wts,b)
            
            
    return svm_classifier

# %%
svm_classifiers=trainSVMs(image_data,labels)

# %%
svm_classifiers[1][2][0]
# Out:
# array([[-0.00280152,  0.00118098,  0.00789759, ..., -0.00681335,
#         -0.00234694,  0.00695298]])

# %%
def binary_predict(x,w,b):
    z=np.dot(x,w.T)+b
    
    if z>0:
        return 1
    else:
        return -1

# %%
def predict(x):
    count=np.zeros((CLASSES,))
    
    for i in range(CLASSES):
        for j in range(i+1,CLASSES):
            w,b=svm_classifiers[i][j]
            
            z=binary_predict(x,w,b)
            
            if (z==1):
                count[j]+=1
            else:
                count[i]+=1
    
    final_prediction=np.argmax(count)
    
    
    return final_prediction

# %%
print(predict(image_data[0]))
print(labels[0])
# Out:
# 1
# 1

# %%
def accuracy(x,y):
    count=0
    
    for i in range (x.shape[0]):
        predic=predict(x[i])
        if (predic==y[i]):
            count+=1
    return count/x.shape[0]

# %%
print(accuracy(image_data,labels))
# Out:
# 0.9605263157894737

# %% [markdown]
# # USING SKLEARN

# %%
from sklearn import svm

# %%
clf=svm.SVC(gamma='scale')

# %%
clf.fit(image_data,labels)
# Out:
# SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
clf.score(image_data,labels)
# Out:
# 0.9703947368421053
